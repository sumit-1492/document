# %%
import pandas as pd

# %% [markdown]
# # reading tsv file from url source

# %%
df = pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df1 = pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv" , sep = "\t")

# %%
df1
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df1.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.tail(7)
# Out:
#       order_id  quantity            item_name  \
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
c = df.groupby('item_name')
c = c.sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
c1 = df.groupby('choice_description')
c1 = c1.sum()
c1 = c1.sort_values(['quantity'], ascending=False)
c1.head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
dollar = lambda x: float(x[1:-1])
df.item_price = df.item_price.apply(dollar)

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
dollar
# Out:
# <function __main__.<lambda>(x)>

# %%
lambda x: float(x[1:-1])
# Out:
# <function __main__.<lambda>(x)>

# %%
revenue = (df['quantity']* df['item_price']).sum()
print('Revenue was: $',revenue)
# Out:
# Revenue was: $ 39237.02

# %%
rev = df['quantity']* df['item_price']
rev
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       33.96
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Length: 4622, dtype: float64

# %%
rev_s = (df['quantity']* df['item_price']).sum()
rev_s
# Out:
# 39237.02

# %%
df[['item_name' , 'item_price']]
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
filtered = df.drop_duplicates(['item_name','quantity'])

# %%
filtered
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 3890      1559         2                  Carnitas Crispy Tacos
# 3973      1592         4                      Canned Soft Drink
# 4152      1660        10                          Bottled Water
# 4354      1738         2                       Steak Soft Tacos
# 4489      1786         4                    Chips and Guacamole
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
one_prod = filtered[filtered.quantity == 1]

# %%
one_prod
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 16           8         1                        Chicken Burrito
# 21          11         1                       Barbacoa Burrito
# 27          14         1                       Carnitas Burrito
# ...

# %%
price_per_item = one_prod[['item_name', 'item_price']]

# %%
price_per_item
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 5                              Chicken Bowl       10.98
# 6                             Side of Chips        1.69
# 7                             Steak Burrito       11.75
# 8                          Steak Soft Tacos        9.25
# 10                      Chips and Guacamole        4.45
# 11                     Chicken Crispy Tacos        8.75
# 12                       Chicken Soft Tacos        8.75
# 16                          Chicken Burrito        8.49
# 21                         Barbacoa Burrito        8.99
# 27                         Carnitas Burrito        8.99
# 28                              Canned Soda        1.09
# 33                            Carnitas Bowl        8.99
# ...

# %%
price_per_item.sort_values(by = "item_price", ascending = False)
# Out:
#                                   item_name  item_price
# 606                        Steak Salad Bowl       11.89
# 1229                    Barbacoa Salad Bowl       11.89
# 1132                    Carnitas Salad Bowl       11.89
# 7                             Steak Burrito       11.75
# 168                   Barbacoa Crispy Tacos       11.75
# 39                            Barbacoa Bowl       11.75
# 738                       Veggie Soft Tacos       11.25
# 186                       Veggie Salad Bowl       11.25
# 62                              Veggie Bowl       11.25
# 57                           Veggie Burrito       11.25
# 250                           Chicken Salad       10.98
# 5                              Chicken Bowl       10.98
# 8                          Steak Soft Tacos        9.25
# 554                   Carnitas Crispy Tacos        9.25
# 237                     Carnitas Soft Tacos        9.25
# 56                      Barbacoa Soft Tacos        9.25
# ...

# %%
df.sort_values(by = "item_price", ascending = False).head()
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
#
#                                      choice_description  item_price
# 3598                                                NaN       44.25
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       35.25
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       35.00
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       35.00
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       33.75

# %%
df.sort_values(by = "item_price", ascending = False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
df.item_name == "Veggie Salad Bowl"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4617    False
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# Name: item_name, Length: 4622, dtype: bool

# %%
df[df.item_name == "Veggie Salad Bowl"]
# Out:
#       order_id  quantity          item_name  \
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description  item_price
# ...

# %% [markdown]
# # reading text file from url source

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt")

# %%
df2
# Out:
#        name calories sodium alcohol cost
# 0              Budweiser 144 15 4.7 0.43
# 1                Schlitz 151 19 4.9 0.43
# 2              Lowenbrau 157 15 0.9 0.48
# 3             Kronenbourg 170 7 5.2 0.73
# 4               Heineken 152 11 5.0 0.77
# 5          Old_Milwaukee 145 23 4.6 0.28
# 6             Augsberger 175 24 5.5 0.40
# 7   Srohs_Bohemian_Style 149 27 4.7 0.42
# 8             Miller_Lite 99 10 4.3 0.43
# 9         Budweiser_Light 113 8 3.7 0.40
# 10                 Coors 140 18 4.6 0.44
# 11           Coors_Light 102 15 4.1 0.46
# 12        Michelob_Light 135 11 4.2 0.50
# 13                 Becks 150 19 4.7 0.76
# 14                  Kirin 149 6 5.0 0.79
# 15      Pabst_Extra_Light 68 15 2.3 0.38
# 16                 Hamms 139 19 4.4 0.43
# 17   Heilemans_Old_Style 144 24 4.9 0.43
# 18     Olympia_Goled_Light 72 6 2.9 0.46
# 19           Schlitz_Light 97 7 4.2 0.47

# %%
df2.columns
# Out:
# Index(['name calories sodium alcohol cost'], dtype='object')

# %%
df3 = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt" , sep = ' ')

# %%
 df3
# Out:
#                     name  calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old_Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            Miller_Lite        99      10      4.3  0.43
# 9        Budweiser_Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11           Coors_Light       102      15      4.1  0.46
# 12        Michelob_Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# ...

# %%
m = max(df3['calories'])
m
# Out:
# 175

# %%
df3.sort_values(by = "calories", ascending = False).head()
# Out:
#           name  calories  sodium  alcohol  cost
# 6   Augsberger       175      24      5.5  0.40
# 3  Kronenbourg       170       7      5.2  0.73
# 2    Lowenbrau       157      15      0.9  0.48
# 4     Heineken       152      11      5.0  0.77
# 1      Schlitz       151      19      4.9  0.43

# %% [markdown]
# # reading csv file from url source

# %%
df4 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv")

# %%
df4
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
df4.columns
# Out:
# Index(['Year', 'Population', 'Total', 'Violent', 'Property', 'Murder',
#        'Forcible_Rape', 'Robbery', 'Aggravated_assault', 'Burglary',
#        'Larceny_Theft', 'Vehicle_Theft'],
#       dtype='object')

# %%
df5 = df4[['Year' , 'Vehicle_Theft']]

# %%
df5
# Out:
#     Year  Vehicle_Theft
# 0   1960         328200
# 1   1961         336000
# 2   1962         366800
# 3   1963         408300
# 4   1964         472800
# 5   1965         496900
# 6   1966         561200
# 7   1967         659800
# 8   1968         783600
# 9   1969         878500
# 10  1970         928400
# 11  1971         948200
# 12  1972         887200
# 13  1973         928800
# 14  1974         977100
# 15  1975        1009600
# 16  1976         966000
# 17  1977         977700
# 18  1978        1004100
# 19  1979        1112800
# 20  1980        1131700
# 21  1981        1087800
# 22  1982        1062400
# 23  1983        1007900
# 24  1984        1032200
# 25  1985        1102900
# 26  1986        1224137
# 27  1987        1288674
# 28  1988        1432900
# 29  1989        1564800
# 30  1990        1635900
# 31  1991        1661700
# 32  1992        1610800
# 33  1993        1563100
# 34  1994        1539300
# 35  1995        1472400
# 36  1996        1394200
# ...

# %%
#most vehicle theft in a year
df5.sort_values(by = "Vehicle_Theft", ascending = False).head()
# Out:
#     Year  Vehicle_Theft
# 31  1991        1661700
# 30  1990        1635900
# 32  1992        1610800
# 29  1989        1564800
# 33  1993        1563100

# %%
df5.sort_values(by = "Vehicle_Theft", ascending = False).head(1)
# Out:
#     Year  Vehicle_Theft
# 31  1991        1661700

# %%
df4.describe()
# Out:
#              Year    Population         Total       Violent      Property  \
# count    55.00000  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   1987.00000  2.461556e+08  1.060315e+07  1.188806e+06  9.412499e+06
# std      16.02082  4.166216e+07  3.175931e+06  4.597107e+05  2.738512e+06
# min    1960.00000  1.793232e+08  3.384200e+06  2.884600e+05  3.095700e+06
# 25%    1973.50000  2.106215e+08  9.096958e+06  9.253150e+05  8.060014e+06
# 50%    1987.00000  2.422829e+08  1.140151e+07  1.322390e+06  1.018259e+07
# 75%    2000.50000  2.833697e+08  1.308449e+07  1.432762e+06  1.160509e+07
# max    2014.00000  3.188571e+08  1.487290e+07  1.932270e+06  1.296110e+07
#
#              Murder  Forcible_Rape        Robbery  Aggravated_assault  \
# count     55.000000      55.000000      55.000000        5.500000e+01
# mean   17317.236364   72714.800000  416449.890909        6.811818e+05
# std     4267.442664   28278.006893  150506.403782        2.960255e+05
# ...

# %%
df4.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
df4.Year = pd.to_datetime(df4.Year)

# %%
df4.Year
# Out:
# 0    1970-01-01 00:00:00.000001960
# 1    1970-01-01 00:00:00.000001961
# 2    1970-01-01 00:00:00.000001962
# 3    1970-01-01 00:00:00.000001963
# 4    1970-01-01 00:00:00.000001964
# 5    1970-01-01 00:00:00.000001965
# 6    1970-01-01 00:00:00.000001966
# 7    1970-01-01 00:00:00.000001967
# 8    1970-01-01 00:00:00.000001968
# 9    1970-01-01 00:00:00.000001969
# 10   1970-01-01 00:00:00.000001970
# 11   1970-01-01 00:00:00.000001971
# 12   1970-01-01 00:00:00.000001972
# 13   1970-01-01 00:00:00.000001973
# 14   1970-01-01 00:00:00.000001974
# 15   1970-01-01 00:00:00.000001975
# 16   1970-01-01 00:00:00.000001976
# 17   1970-01-01 00:00:00.000001977
# 18   1970-01-01 00:00:00.000001978
# 19   1970-01-01 00:00:00.000001979
# 20   1970-01-01 00:00:00.000001980
# 21   1970-01-01 00:00:00.000001981
# 22   1970-01-01 00:00:00.000001982
# 23   1970-01-01 00:00:00.000001983
# 24   1970-01-01 00:00:00.000001984
# 25   1970-01-01 00:00:00.000001985
# 26   1970-01-01 00:00:00.000001986
# ...

# %%
df4.Year = pd.to_datetime(df4.Year,format = '%y')

# %%
df4.Year
# Out:
# 0    1970-01-01 00:00:00.000001960
# 1    1970-01-01 00:00:00.000001961
# 2    1970-01-01 00:00:00.000001962
# 3    1970-01-01 00:00:00.000001963
# 4    1970-01-01 00:00:00.000001964
# 5    1970-01-01 00:00:00.000001965
# 6    1970-01-01 00:00:00.000001966
# 7    1970-01-01 00:00:00.000001967
# 8    1970-01-01 00:00:00.000001968
# 9    1970-01-01 00:00:00.000001969
# 10   1970-01-01 00:00:00.000001970
# 11   1970-01-01 00:00:00.000001971
# 12   1970-01-01 00:00:00.000001972
# 13   1970-01-01 00:00:00.000001973
# 14   1970-01-01 00:00:00.000001974
# 15   1970-01-01 00:00:00.000001975
# 16   1970-01-01 00:00:00.000001976
# 17   1970-01-01 00:00:00.000001977
# 18   1970-01-01 00:00:00.000001978
# 19   1970-01-01 00:00:00.000001979
# 20   1970-01-01 00:00:00.000001980
# 21   1970-01-01 00:00:00.000001981
# 22   1970-01-01 00:00:00.000001982
# 23   1970-01-01 00:00:00.000001983
# 24   1970-01-01 00:00:00.000001984
# 25   1970-01-01 00:00:00.000001985
# 26   1970-01-01 00:00:00.000001986
# ...

# %%
df4 = df4.set_index('year')

# %%
df4
# Out:
#                                Population     Total  Violent  Property  \
# Year
# 1970-01-01 00:00:00.000001960   179323175   3384200   288460   3095700
# 1970-01-01 00:00:00.000001961   182992000   3488000   289390   3198600
# 1970-01-01 00:00:00.000001962   185771000   3752200   301510   3450700
# 1970-01-01 00:00:00.000001963   188483000   4109500   316970   3792500
# 1970-01-01 00:00:00.000001964   191141000   4564600   364220   4200400
# 1970-01-01 00:00:00.000001965   193526000   4739400   387390   4352000
# 1970-01-01 00:00:00.000001966   195576000   5223500   430180   4793300
# 1970-01-01 00:00:00.000001967   197457000   5903400   499930   5403500
# 1970-01-01 00:00:00.000001968   199399000   6720200   595010   6125200
# 1970-01-01 00:00:00.000001969   201385000   7410900   661870   6749000
# 1970-01-01 00:00:00.000001970   203235298   8098000   738820   7359200
# 1970-01-01 00:00:00.000001971   206212000   8588200   816500   7771700
# ...

# %%
df4.sort_values(by = "Year", ascending = False)
# Out:
#                                Population     Total  Violent  Property  \
# Year
# 1970-01-01 00:00:00.000002014   318857056   9475816  1197987   8277829
# 1970-01-01 00:00:00.000002013   316497531   9850445  1199684   8650761
# 1970-01-01 00:00:00.000002012   313873685  10219059  1217067   9001992
# 1970-01-01 00:00:00.000002011   311587816  10258774  1206031   9052743
# 1970-01-01 00:00:00.000002010   309330219  10363873  1251248   9112625
# 1970-01-01 00:00:00.000002009   307006550  10762956  1325896   9337060
# 1970-01-01 00:00:00.000002008   304374846  11160543  1392628   9767915
# 1970-01-01 00:00:00.000002007   301621157  11251828  1408337   9843481
# 1970-01-01 00:00:00.000002006   299398484  11401511  1418043   9983568
# 1970-01-01 00:00:00.000002005   296507061  11565499  1390745  10174754
# 1970-01-01 00:00:00.000002004   293656842  11679474  1360088  10319386
# 1970-01-01 00:00:00.000002003   290690788  11826538  1383676  10442862
# ...

# %%
df4.sort_values(by = "Year", ascending = False).sum()
# Out:
# Population            13538557224
# Total                   583173026
# Violent                  65384309
# Property                517687418
# Murder                     952448
# Forcible_Rape             3999314
# Robbery                  22904744
# Aggravated_assault       37464999
# Burglary                133320955
# Larceny_Theft           327797108
# Vehicle_Theft            56573743
# dtype: int64

# %%
c3 = df4.resample('10AS').sum()

# %%
c3
# Out:
#              Population      Total   Violent   Property  Murder  \
# Year
# 1970-01-01  13538557224  583173026  65384309  517687418  952448
#
#             Forcible_Rape   Robbery  Aggravated_assault   Burglary  \
# Year
# 1970-01-01        3999314  22904744            37464999  133320955
#
#             Larceny_Theft  Vehicle_Theft
# Year
# 1970-01-01      327797108       56573743

# %%
df4.resample('10AS')

# %%
p1 =df4['Population'].resample('10AS').max()

# %%
p1
# Out:
# Year
# 1970-01-01    318857056
# Freq: 10AS-JAN, Name: Population, dtype: int64

# %%
df4['Population'] = p1
df4
# Out:
#                                Population     Total  Violent  Property  \
# Year
# 1970-01-01 00:00:00.000001960         NaN   3384200   288460   3095700
# 1970-01-01 00:00:00.000001961         NaN   3488000   289390   3198600
# 1970-01-01 00:00:00.000001962         NaN   3752200   301510   3450700
# 1970-01-01 00:00:00.000001963         NaN   4109500   316970   3792500
# 1970-01-01 00:00:00.000001964         NaN   4564600   364220   4200400
# 1970-01-01 00:00:00.000001965         NaN   4739400   387390   4352000
# 1970-01-01 00:00:00.000001966         NaN   5223500   430180   4793300
# 1970-01-01 00:00:00.000001967         NaN   5903400   499930   5403500
# 1970-01-01 00:00:00.000001968         NaN   6720200   595010   6125200
# 1970-01-01 00:00:00.000001969         NaN   7410900   661870   6749000
# 1970-01-01 00:00:00.000001970         NaN   8098000   738820   7359200
# 1970-01-01 00:00:00.000001971         NaN   8588200   816500   7771700
# ...

# %%
df4.iloc[:3]
# Out:
#                                Population    Total  Violent  Property  Murder  \
# Year
# 1970-01-01 00:00:00.000001960         NaN  3384200   288460   3095700    9110
# 1970-01-01 00:00:00.000001961         NaN  3488000   289390   3198600    8740
# 1970-01-01 00:00:00.000001962         NaN  3752200   301510   3450700    8530
#
#                                Forcible_Rape  Robbery  Aggravated_assault  \
# Year
# 1970-01-01 00:00:00.000001960          17190   107840              154320
# 1970-01-01 00:00:00.000001961          17220   106670              156760
# 1970-01-01 00:00:00.000001962          17550   110860              164570
#
#                                Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1970-01-01 00:00:00.000001960    912100        1855400         328200
# 1970-01-01 00:00:00.000001961    949600        1913000         336000
# 1970-01-01 00:00:00.000001962    994300        2089600         366800

# %%
df4.loc[:, ['Murder', 'Robbery']]
# Out:
#                                Murder  Robbery
# Year
# 1970-01-01 00:00:00.000001960    9110   107840
# 1970-01-01 00:00:00.000001961    8740   106670
# 1970-01-01 00:00:00.000001962    8530   110860
# 1970-01-01 00:00:00.000001963    8640   116470
# 1970-01-01 00:00:00.000001964    9360   130390
# 1970-01-01 00:00:00.000001965    9960   138690
# 1970-01-01 00:00:00.000001966   11040   157990
# 1970-01-01 00:00:00.000001967   12240   202910
# 1970-01-01 00:00:00.000001968   13800   262840
# 1970-01-01 00:00:00.000001969   14760   298850
# 1970-01-01 00:00:00.000001970   16000   349860
# 1970-01-01 00:00:00.000001971   17780   387700
# 1970-01-01 00:00:00.000001972   18670   376290
# 1970-01-01 00:00:00.000001973   19640   384220
# 1970-01-01 00:00:00.000001974   20710   442400
# 1970-01-01 00:00:00.000001975   20510   470500
# 1970-01-01 00:00:00.000001976   18780   427810
# 1970-01-01 00:00:00.000001977   19120   412610
# 1970-01-01 00:00:00.000001978   19560   426930
# ...

# %%
df4[['Murder', 'Robbery']].head()
# Out:
#                                Murder  Robbery
# Year
# 1970-01-01 00:00:00.000001960    9110   107840
# 1970-01-01 00:00:00.000001961    8740   106670
# 1970-01-01 00:00:00.000001962    8530   110860
# 1970-01-01 00:00:00.000001963    8640   116470
# 1970-01-01 00:00:00.000001964    9360   130390

# %%
df4.loc[df4.index[[3, 4, 8]], ['Murder', 'Robbery']]
# Out:
#                                Murder  Robbery
# Year
# 1970-01-01 00:00:00.000001963    8640   116470
# 1970-01-01 00:00:00.000001964    9360   130390
# 1970-01-01 00:00:00.000001968   13800   262840

# %%
df4[df4['Murder']>24000]
# Out:
#                                Population     Total  Violent  Property  \
# Year
# 1970-01-01 00:00:00.000001991         NaN  14872900  1911770  12961100
# 1970-01-01 00:00:00.000001993         NaN  14144800  1926020  12218800
#
#                                Murder  Forcible_Rape  Robbery  \
# Year
# 1970-01-01 00:00:00.000001991   24700         106590   687730
# 1970-01-01 00:00:00.000001993   24530         106010   659870
#
#                                Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1970-01-01 00:00:00.000001991             1092740   3157200        8142200
# 1970-01-01 00:00:00.000001993             1135610   2834800        7820900
#
#                                Vehicle_Theft
# Year
# 1970-01-01 00:00:00.000001991        1661700
# 1970-01-01 00:00:00.000001993        1563100

# %%
df4[df4['Murder'].between(20000,24000)]
# Out:
#                                Population     Total  Violent  Property  \
# Year
# 1970-01-01 00:00:00.000001974         NaN  10253400   974720   9278700
# 1970-01-01 00:00:00.000001975         NaN  11292400  1039710  10252700
# 1970-01-01 00:00:00.000001979         NaN  12249500  1208030  11041500
# 1970-01-01 00:00:00.000001980         NaN  13408300  1344520  12063700
# 1970-01-01 00:00:00.000001981         NaN  13423800  1361820  12061900
# 1970-01-01 00:00:00.000001982         NaN  12974400  1322390  11652000
# 1970-01-01 00:00:00.000001986         NaN  13211869  1489169  11722700
# 1970-01-01 00:00:00.000001987         NaN  13508700  1483999  12024700
# 1970-01-01 00:00:00.000001988         NaN  13923100  1566220  12356900
# 1970-01-01 00:00:00.000001989         NaN  14251400  1646040  12605400
# 1970-01-01 00:00:00.000001990         NaN  14475600  1820130  12655500
# 1970-01-01 00:00:00.000001992         NaN  14438200  1932270  12505900
# ...

# %%
df4.groupby('Year')['Murder'].mean()
# Out:
# Year
# 1970-01-01 00:00:00.000001960     9110
# 1970-01-01 00:00:00.000001961     8740
# 1970-01-01 00:00:00.000001962     8530
# 1970-01-01 00:00:00.000001963     8640
# 1970-01-01 00:00:00.000001964     9360
# 1970-01-01 00:00:00.000001965     9960
# 1970-01-01 00:00:00.000001966    11040
# 1970-01-01 00:00:00.000001967    12240
# 1970-01-01 00:00:00.000001968    13800
# 1970-01-01 00:00:00.000001969    14760
# 1970-01-01 00:00:00.000001970    16000
# 1970-01-01 00:00:00.000001971    17780
# 1970-01-01 00:00:00.000001972    18670
# 1970-01-01 00:00:00.000001973    19640
# 1970-01-01 00:00:00.000001974    20710
# 1970-01-01 00:00:00.000001975    20510
# 1970-01-01 00:00:00.000001976    18780
# 1970-01-01 00:00:00.000001977    19120
# 1970-01-01 00:00:00.000001978    19560
# 1970-01-01 00:00:00.000001979    21460
# 1970-01-01 00:00:00.000001980    23040
# 1970-01-01 00:00:00.000001981    22520
# 1970-01-01 00:00:00.000001982    21010
# 1970-01-01 00:00:00.000001983    19310
# ...

# %%
df4.sort_values(by=['Murder', 'Violent'], ascending=[False, True])
# Out:
#                                Population     Total  Violent  Property  \
# Year
# 1970-01-01 00:00:00.000001991         NaN  14872900  1911770  12961100
# 1970-01-01 00:00:00.000001993         NaN  14144800  1926020  12218800
# 1970-01-01 00:00:00.000001992         NaN  14438200  1932270  12505900
# 1970-01-01 00:00:00.000001990         NaN  14475600  1820130  12655500
# 1970-01-01 00:00:00.000001994         NaN  13989500  1857670  12131900
# 1970-01-01 00:00:00.000001980         NaN  13408300  1344520  12063700
# 1970-01-01 00:00:00.000001981         NaN  13423800  1361820  12061900
# 1970-01-01 00:00:00.000001995         NaN  13862700  1798790  12063900
# 1970-01-01 00:00:00.000001989         NaN  14251400  1646040  12605400
# 1970-01-01 00:00:00.000001979         NaN  12249500  1208030  11041500
# 1970-01-01 00:00:00.000001982         NaN  12974400  1322390  11652000
# 1970-01-01 00:00:00.000001974         NaN  10253400   974720   9278700
# ...

# %% [markdown]
# # reading dat from csv file from url source

# %%
df6 = pd.read_csv("https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv")

# %%
df6
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...
